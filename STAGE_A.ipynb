# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#importing csv dataset
data=pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv',encoding='latin-1')

# %%
data
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# ...

# %%
correlation_matrix = data.corr()
# Out:
# <ipython-input-5-19e8f3752a40>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
print(correlation_matrix)
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
data['Element'].count()
# Out:
# 60943

# %%
# Filter data for Madagascar and the year 2015
madagascar_2015 = data[(data['Area'] == 'Madagascar') & (data['Y2015'])]

# %%
print(madagascar_2015)
# Out:
#        Area Code        Area  Item Code              Item  Element Code  \
# 30715        129  Madagascar       2501        Population           511
# 30717        129  Madagascar       2901       Grand Total           664
# 30718        129  Madagascar       2901       Grand Total           674
# 30719        129  Madagascar       2901       Grand Total           684
# 30720        129  Madagascar       2903  Vegetal Products           664
# ...          ...         ...        ...               ...           ...
# 32147        129  Madagascar       2899     Miscellaneous          5301
# 32149        129  Madagascar       2899     Miscellaneous          5142
# 32150        129  Madagascar       2899     Miscellaneous           645
# 32152        129  Madagascar       2899     Miscellaneous           674
# 32153        129  Madagascar       2899     Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# ...

# %%
# Sum the 'Protein_Supply_Quantity' column for Madagascar in 2015
total_protein_supply = madagascar_2015.sum()

# %%
print(total_protein_supply)
# Out:
# Area Code                                                  101007
# Area            MadagascarMadagascarMadagascarMadagascarMadaga...
# Item Code                                                 2128948
# Item            PopulationGrand TotalGrand TotalGrand TotalVeg...
# Element Code                                              2811467
# Element         Total Population - Both sexesFood supply (kcal...
# Unit            1000 personskcal/capita/dayg/capita/dayg/capit...
# Y2014                                                   128985.25
# Y2015                                                    126674.9
# Y2016                                                   128952.17
# Y2017                                                   131075.68
# Y2018                                                   134434.33
# dtype: object

# %%
sum1 = data.groupby(['Y2015', 'Y2018']).sum()
# Out:
# <ipython-input-12-e97910279b0b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sum1 = data.groupby(['Y2015', 'Y2018']).sum()

# %%
sum1
# Out:
#                      Area Code  Item Code  Element Code     Y2014     Y2016  \
# Y2015     Y2018
# -3161.0   -296.0           202       2905          5072     439.0   -1499.0
# -2152.0   -597.0           202       2514          5072     626.0   -1324.0
# -1284.0    1898.0          276       2905          5072    4569.0    3266.0
# -907.0    -529.0           251       2905          5072     520.0    -506.0
# -887.0     163.0           276       2518          5072    3134.0    2432.0
# ...                        ...        ...           ...       ...       ...
#  92443.0   98424.0          59       2501           511   90425.0   94447.0
#  100835.0  109224.0        238       2501           511   98094.0  103603.0
#  110798.0  117038.0        159       2907          5301  108756.0  116483.0
#  111663.0  118172.0        159       2907          5511  109593.0  119330.0
#  181137.0  195875.0        159       2501           511  176405.0  185960.0
#
#                         Y2017
# ...

# %%
total_sum = data[['Y2015', 'Y2018']].sum()
print(total_sum)
# Out:
# Y2015    8032340.23
# Y2018    8554629.96
# dtype: float64

# %%
data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
data['Y2017'].mean()
# Out:
# 140.9177648602722

# %%
data['Y2017'].std()
# Out:
# 1671.8623590567995

# %%
S = [['him', 'sell'], [90, 28, 43]]
S[0][1][1]
# Out:
# 'e'

# %%
data['Area'].count()
# Out:
# 60943

# %%
data.shape
# Out:
# (60943, 12)

# %%
data.groupby(['Area', 'Y2017']).sum()
# Out:
# <ipython-input-21-92e6230fdde2>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['Area', 'Y2017']).sum()
#                    Area Code  Item Code  Element Code    Y2014    Y2015  \
# Area     Y2017
# Algeria  -81.0             8       5536         10144     60.0    -10.0
#          -47.0             8       5438         10144    312.0     70.0
#          -11.0             4       2563          5072    -29.0    -11.0
#          -6.0              4       2680          5072      1.0      4.0
#          -5.0             12       8257         15412    -24.0    -24.0
# ...                      ...        ...           ...      ...      ...
# Zimbabwe  1891.0         181       2901           664   1986.0   1912.0
# ...

# %%
data.groupby(['Element']).sum()
# Out:
# <ipython-input-22-3464703521ca>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['Element']).sum()
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# ...
